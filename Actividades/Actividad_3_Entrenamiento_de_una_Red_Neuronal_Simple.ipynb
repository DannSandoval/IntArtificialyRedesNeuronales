# %% [markdown]
# # **Actividad 3 🌝**
# # **Entrenamiento de una Red Neuronal Simple ⚡**
#
#
# ---
# **Nombre:** Daniela Sandoval Castillo
#
# **Matrícula:** 1970534
#
# **Clase:** L,M,V
#
# **Hora clase:** N1

# %%
# Librerias
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from keras.utils import np_utils

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
X_train = np.reshape( x_train, (x_train.shape[0],x_train.shape[1]*x_train.shape[2]) )
X_test = np.reshape( x_test, (x_test.shape[0],x_test.shape[1]*x_test.shape[2]) )

# %%
X_train = X_train/255.0
X_test = X_test/255.0

# %%
ids_imgs = np.random.randint(0,x_train.shape[0],25)
for i in range(len(ids_imgs)):
	img = x_train[ids_imgs[i]]
	plt.subplot(5,5,i+1)
	plt.imshow(img, cmap=plt.cm.binary)
	plt.axis('off')
	plt.title(y_train[ids_imgs[i]])
plt.suptitle('Digitos escritos a mano')
plt.show()

# %%
nclases = 10
y_train = np_utils.to_categorical(y_train,nclases)
y_test = np_utils.to_categorical(y_test,nclases)

# %%
nimagen = 59999
plt.imshow(x_train[nimagen,:].reshape(28,28), cmap='gray_r')
plt.title('Imagen ejemplo - Categoría: ' + str(np.argmax(y_train[nimagen])))
plt.axis('off')
plt.show()

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 9s 4ms/step - loss: 2.2927 - accuracy: 0.8551
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3514 - accuracy: 0.9138
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2713 - accuracy: 0.9324
# Epoch 4/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2423 - accuracy: 0.9380
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2271 - accuracy: 0.9441
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2126 - accuracy: 0.9471
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1978 - accuracy: 0.9494
# Epoch 8/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1884 - accuracy: 0.9520
# Epoch 9/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1845 - accuracy: 0.9548
# Epoch 10/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1792 - accuracy: 0.9567

# %%
test_loss, test_acc = model.evaluate(x_test,  y_test, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 0.3342 - accuracy: 0.9419 - 621ms/epoch - 2ms/step
#
# Test accuracy: 0.9419000148773193
